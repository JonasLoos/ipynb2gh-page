# %% [markdown]
# # This is an example notebook
#
# This notebook is not executed by the GitHub action, but rather converted to html as is. Make sure to `Run All` before committing the notebook.
#
# ## Examples
#
# some *nice* math:
# $$ X = \frac{1}{n} \sum_{i=1}^{n} \alpha_i $$
#
# ```
# some code block
# ...
# ```

# %%
# some real code and an example plot

import matplotlib.pyplot as plt
import numpy as np

n = 42
plt.scatter(*np.random.uniform(size=(2,n)), c=np.random.uniform(size=n))
plt.show()
print(f'plotted {n} points!')
# Out:
# plotted 42 points!
